# %%
# !pip install wordcloud
# !pip install pandas
# !pip install seaborn
# !pip install scikit-learn
# !pip install bs4
# !pip install nltk
# Out:
# Requirement already satisfied: wordcloud in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (1.8.1)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from wordcloud) (9.0.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from seaborn) (1.4.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.21.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: bs4 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Requirement already satisfied: nltk in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (3.6.7)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (2022.1.18)
# Requirement already satisfied: click in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\tensorflow\lib\site-packages (from click->nltk) (0.4.4)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import string
import re
import matplotlib.pyplot as plt
import math
from matplotlib import rc
from sklearn.model_selection import train_test_split
from collections import Counter, defaultdict
from bs4 import BeautifulSoup
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

get_ipython().run_line_magic('matplotlib', 'inline')

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
train = pd.read_csv(r"C:\Users\Admin\Downloads\labeledTrainData.tsv", delimiter="\t")
test = pd.read_csv(r"C:\Users\Admin\Downloads\testData.tsv", delimiter="\t")

# %%
train.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
f = sns.countplot(x='sentiment', data=train)
f.set_title("Sentiment distribution")
f.set_xticklabels(['Negative', 'Positive'])
plt.xlabel("");

# %%
text = " ".join(review for review in train.review)


wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="black", stopwords=stopwords.words("english")).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show();

# %%
class Tokenizer:
  
  def clean(self, text):
      no_html = BeautifulSoup(text).get_text()
      clean = re.sub("[^a-z\s]+", " ", no_html, flags=re.IGNORECASE)
      return re.sub("(\s+)", " ", clean)

 
  def tokenize(self, text):
      clean = self.clean(text).lower()
      stopwords_en = stopwords.words("english")
      return [w for w in re.split("\W+", clean) if not w in stopwords_en]

# %%
class MultinomialNaiveBayes:
  
    def __init__(self, classes, tokenizer):
      self.tokenizer = tokenizer
      self.classes = classes
      
    def group_by_class(self, X, y):
      data = dict()
      for c in self.classes:
        data[c] = X[np.where(y == c)]
      return data
           
    def fit(self, X, y):
        self.n_class_items = {}
        self.log_class_priors = {}
        self.word_counts = {}
        self.vocab = set()

        n = len(X)
        
        grouped_data = self.group_by_class(X, y)
        
        for c, data in grouped_data.items():
          self.n_class_items[c] = len(data)
          self.log_class_priors[c] = math.log(self.n_class_items[c] / n)
          self.word_counts[c] = defaultdict(lambda: 0)
          
          for text in data:
            counts = Counter(self.tokenizer.tokenize(text))
            for word, count in counts.items():
                if word not in self.vocab:
                    self.vocab.add(word)

                self.word_counts[c][word] += count
                
        return self
      
    def laplace_smoothing(self, word, text_class):
      num = self.word_counts[text_class][word] + 1
      denom = self.n_class_items[text_class] + len(self.vocab)
      return math.log(num / denom)
      
    def predict(self, X):
        result = []
        for text in X:
          
          class_scores = {c: self.log_class_priors[c] for c in self.classes}

          words = set(self.tokenizer.tokenize(text))
          for word in words:
              if word not in self.vocab: continue

              for c in self.classes:
                
                log_w_given_c = self.laplace_smoothing(word, c)
                class_scores[c] += log_w_given_c
                
          result.append(max(class_scores, key=class_scores.get))

        return result

# %%
X = train['review'].values
y = train['sentiment'].values
  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)

# %%
MNB = MultinomialNaiveBayes(
    classes=np.unique(y), 
    tokenizer=Tokenizer()
).fit(X_train, y_train)

# %%
y_hat = MNB.predict(X_test)

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.8556

# %%
print(classification_report(y_test, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      2481
#            1       0.83      0.90      0.86      2519
#
#     accuracy                           0.86      5000
#    macro avg       0.86      0.86      0.86      5000
# weighted avg       0.86      0.86      0.86      5000

# %%
cnf_matrix = confusion_matrix(y_test, y_hat)
cnf_matrix
# Out:
# array([[2021,  460],
#        [ 262, 2257]], dtype=int64)

# %%
class_names = ["Negative", "Positive"]
fig,ax = plt.subplots()


sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="Blues", fmt="d", cbar=False, xticklabels=class_names, yticklabels=class_names)
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('Actual sentiment')
plt.xlabel('Predicted sentiment');
